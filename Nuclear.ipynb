# %%
import pandas as pd

# %%
url = 'https://datosmacro.expansion.com/energia-y-medio-ambiente/emisiones-co2/espana'

# %%
pd.read_html(url)[0]
# Out:
#     Fecha  CO2 Totales Mt  CO2 Kg/1000$  CO2 t per capita
# 0    2021          231914          13.0               499
# 1    2020          212467          12.0               457
# 2    2019          256805          13.0               553
# 3    2018          274374          15.0               591
# 4    2017          280844          15.0               606
# 5    2016          264696          15.0               571
# 6    2015          273714          16.0               590
# 7    2014          257632          15.0               554
# 8    2013          260356          16.0               558
# 9    2012          287060          17.0               613
# 10   2011          293205          17.0               625
# 11   2010          291328          17.0               623
# 12   2009          304396          18.0               655
# 13   2008          344169          19.0               748
# 14   2007          375974          21.0               828
# ...

# %%
url1 = 'https://datosmacro.expansion.com/energia-y-medio-ambiente/electricidad-generacion/espana'

# %%
pd.read_html(url1)[0]
# Out:
#     Fecha  Capacidad instalada MW  Generación GWh  \
# 0    2022                 119.449         276.368
# 1    2021                 113.489         260.011
# 2    2020                 110.825         251.399
# 3    2019                 110.004         260.829
# 4    2018                 104.101         260.982
# 5    2017                 104.040         262.306
# 6    2016                 104.557         261.836
# 7    2015                 105.657         267.454
# 8    2014                 105.758         266.512
# 9    2013                 105.830         273.286
# 10   2012                 105.243         283.119
# 11   2011                 102.898         279.354
# 12   2010                 101.371         288.527
# 13   2009                  97.751         280.074
# 14   2008                  94.166         295.894
# 15   2007                  88.057         288.137
# 16   2006                  81.509         279.967
# 17   2005                  77.248         268.934
# ...

# %%
url2 = 'https://datosmacro.expansion.com/energia-y-medio-ambiente/electricidad-consumo/espana'

# %%
pd.read_html(url2)[0]
# Out:
#     Fecha  Generación GWh  Consumo GWh Consumo per capita kWh
# 0    2022         276.368      250.516                5.213,9
# 1    2021         260.011      256.546                5.402,4
# 2    2020         251.399      250.051                5.275,5
# 3    2019         260.829      264.664                5.591,6
# 4    2018         260.982      268.886                5.728,7
# 5    2017         262.306      267.867                5.741,0
# 6    2016         261.836      264.666                5.688,4
# 7    2015         267.454      262.808                5.659,1
# 8    2014         266.512      257.720                5.548,4
# 9    2013         273.286      260.598                5.602,8
# 10   2012         283.119      266.860                5.710,9
# 11   2011         279.354      270.022                5.767,5
# 12   2010         288.527      275.736                5.908,6
# 13   2009         280.074      268.193                5.769,3
# ...

# %%
url3 = 'https://world-nuclear.org/information-library/facts-and-figures/nuclear-generation-by-country.aspx'

# %%
pd.read_html(url3)[0]
# Out:
#          Country or area Nuclear share of electricity (%)                    \
#       Unnamed: 0_level_1                             2012  2013  2014  2015
# 0              Argentina                              4.7   4.4   4.0   4.8
# 1                Armenia                             26.6  29.2  30.7  34.5
# 2                Belarus                              0.0   0.0   0.0   0.0
# 3                Belgium                             51.0  52.1  47.5  37.5
# 4                 Brazil                              3.1   2.8   2.9   2.8
# 5               Bulgaria                             31.6  30.7  31.8  31.3
# 6                 Canada                             15.3  16.0  16.8  16.6
# 7                 China:                              NaN   NaN   NaN   NaN
# 8             - Mainland                              2.0   2.1   2.4   3.0
# 9               - Taiwan                             18.4  19.1  18.9  16.3
# ...

# %%
url4 = 'https://datosmacro.expansion.com/energia-y-medio-ambiente/emisiones-co2'

# %%
pd.read_html(url4)[0]
# Out:
#               Países CO2 Totales Mt  CO2 Kg/1000$  CO2 t per capita  \
# 0         España [+]         231914            13               499
# 1       Alemania [+]         665884            15               806
# 2    Reino Unido [+]         335363            11               495
# 3        Francia [+]         302327            10               458
# 4         Italia [+]         319669            13               541
# ..               ...            ...           ...               ...
# 179        Samoa [+]           0360            31               178
# 180        Yemen [+]          12047            10                39
# 181    Sudáfrica [+]         435523            55               734
# 182       Zambia [+]           7011            11                36
# 183     Zimbabue [+]          12293            23                68
#
#      CO2 t per capita.1   Var.
# 0                   NaN  9,18%
# 1                   NaN  5,78%
# 2                   NaN  4,59%
# ...

# %%
url5 = 'https://datosmacro.expansion.com/energia-y-medio-ambiente/electricidad-generacion'

# %%
pd.read_html(url5)[0]
# Out:
#               Países  Fecha Capacidad instalada MW Generación GWh  \
# 0         España [+]   2022                119.449        276.368
# 1       Alemania [+]   2021                250.385        557.144
# 2    Reino Unido [+]   2021                108.743        288.609
# 3        Francia [+]   2021                142.216        530.418
# 4         Italia [+]   2021                120.884        274.179
# ..               ...    ...                    ...            ...
# 183        Samoa [+]   2021                     51            178
# 184        Yemen [+]   2021                  1.772          3.521
# 185    Sudáfrica [+]   2021                 63.276        221.500
# 186       Zambia [+]   2021                  3.365         17.714
# 187     Zimbabue [+]   2021                  2.476          8.031
#
#     Capacidad instalada renovable MW Generación renovable GWh  \
# 0                             70.813                  116.695
# ...

# %%
url6 = 'https://datosmacro.expansion.com/energia-y-medio-ambiente/electricidad-consumo'

# %%
pd.read_html(url6)[0]
# Out:
#               Países  Fecha Generación GWh Consumo GWh Consumo per capita kWh  \
# 0         España [+]   2022        276.368     250.516                5.213,9
# 1       Alemania [+]   2021        557.144     511.660                6.147,0
# 2    Reino Unido [+]   2021        288.609     287.319                4.283,2
# 3        Francia [+]   2021        530.418     447.447                6.592,5
# 4         Italia [+]   2021        274.179     299.922                5.080,8
# ..               ...    ...            ...         ...                    ...
# 183        Samoa [+]   2021            178         163                   8125
# 184        Yemen [+]   2021          3.521       2.931                    898
# 185    Sudáfrica [+]   2021        221.500     191.441                3.183,1
# 186       Zambia [+]   2021         17.714      14.321                   7354
# 187     Zimbabue [+]   2021          8.031       8.340                   5215
#
# ...

# %%
url7 = 'https://world-nuclear.org/information-library/facts-and-figures/uranium-production-figures.aspx'

# %%
pd.read_html(url7)[0]
# Out:
#                 Country   2013   2014   2015   2016   2017   2018   2019  \
# 0            Kazakhstan  22451  23127  23607  24689  23321  21705  22808
# 1                Canada   9331   9124  13325  14039  13116   7001   6938
# 2               Namibia   4323   3255   2993   3654   4224   5525   5476
# 3             Australia   6350   5001   5654   6315   5882   6517   6613
# 4     Uzbekistan (est.)   2400   2400   2385   3325   3400   3450   3500
# 5                Russia   3135   2990   3055   3004   2917   2904   2911
# 6                 Niger   4518   4057   4116   3479   3449   2911   2983
# 7          China (est.)   1500   1500   1616   1616   1692   1885   1885
# 8          India (est.)    385    285    385    385    421    423    308
# 9   South Africa (est.)    531    573    393    490    308    346    346
# 10              Ukraine    922    926   1200    808    707    790    800
# 11                  USA   1792   1919   1256   1125    940    582     58
# ...
