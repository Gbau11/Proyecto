# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('Energia2.csv')

# %%
df
# Out:
#           country  year  renewable-electricity-generating-capacity-per-capita  \
# 0     Afghanistan  2000                                               9.22
# 1     Afghanistan  2001                                               8.86
# 2     Afghanistan  2002                                               8.47
# 3     Afghanistan  2003                                               8.09
# 4     Afghanistan  2004                                               7.75
# ...           ...   ...                                                ...
# 3644     Zimbabwe  2016                                              62.88
# 3645     Zimbabwe  2017                                              62.33
# 3646     Zimbabwe  2018                                              82.53
# 3647     Zimbabwe  2019                                              81.40
# 3648     Zimbabwe  2020                                              80.61
#
# ...

# %%
df.columns = df.columns.str.lower().str.replace('-', '_')

df
# Out:
#           country  year  renewable_electricity_generating_capacity_per_capita  \
# 0     Afghanistan  2000                                               9.22
# 1     Afghanistan  2001                                               8.86
# 2     Afghanistan  2002                                               8.47
# 3     Afghanistan  2003                                               8.09
# 4     Afghanistan  2004                                               7.75
# ...           ...   ...                                                ...
# 3644     Zimbabwe  2016                                              62.88
# 3645     Zimbabwe  2017                                              62.33
# 3646     Zimbabwe  2018                                              82.53
# 3647     Zimbabwe  2019                                              81.40
# 3648     Zimbabwe  2020                                              80.61
#
# ...

# %%
df.isna().sum()
# Out:
# country                                                               0
# year                                                                  0
# renewable_electricity_generating_capacity_per_capita                931
# renewable_energy_share_in_the_total_final_energy_consumption_(%)    194
# electricity_from_fossil_fuels_(twh)                                  21
# electricity_from_nuclear_(twh)                                      126
# electricity_from_renewables_(twh)                                    21
# low_carbon_electricity_(%_electricity)                               42
# primary_energy_consumption_per_capita_(kwh/person)                    0
# energy_intensity_level_of_primary_energy_(mj/$2017_ppp_gdp)         207
# value_co2_emissions_kt_by_country                                   428
# gdp_growth                                                          317
# gdp_per_capita                                                      282
# ...

# %%
df['renewable_electricity_generating_capacity_per_capita'].tail(60)
# Out:
# 3589      0.00
# 3590      0.00
# 3591      0.00
# 3592      0.00
# 3593      0.00
# 3594      0.04
# 3595      0.04
# 3596      0.04
# 3597      0.05
# 3598      0.06
# 3599      0.09
# 3600      0.19
# 3601      2.26
# 3602      2.94
# 3603      3.59
# 3604      8.77
# 3605      8.57
# 3606      8.48
# 3607    173.03
# 3608    168.56
# 3609    164.26
# 3610    154.77
# 3611    150.84
# 3612    146.95
# 3613    143.12
# 3614    134.61
# 3615    133.35
# 3616    130.26
# 3617    142.25
# 3618    138.01
# 3619    134.28
# 3620    154.25
# 3621    149.51
# 3622    145.55
# 3623    148.58
# 3624    144.85
# 3625    140.76
# 3626    142.11
# 3627    138.23
# 3628     61.42
# 3629     61.20
# 3630     62.72
# 3631     62.58
# 3632     62.38
# 3633     62.09
# 3634     61.68
# 3635     61.18
# 3636     67.35
# 3637     66.60
# 3638     65.79
# 3639     66.20
# 3640     65.14
# 3641     64.44
# 3642     63.38
# 3643     63.54
# 3644     62.88
# 3645     62.33
# 3646     82.53
# ...

# %%
valores_nulos = df[df['renewable_electricity_generating_capacity_per_capita'].isnull()]

valores_nulos.head(60)
# Out:
#        country  year  renewable_electricity_generating_capacity_per_capita  \
# 21     Albania  2000                                                NaN
# 22     Albania  2001                                                NaN
# 23     Albania  2002                                                NaN
# 24     Albania  2003                                                NaN
# 25     Albania  2004                                                NaN
# 26     Albania  2005                                                NaN
# 27     Albania  2006                                                NaN
# 28     Albania  2007                                                NaN
# 29     Albania  2008                                                NaN
# 30     Albania  2009                                                NaN
# 31     Albania  2010                                                NaN
# 32     Albania  2011                                                NaN
# ...

# %%
df['renewable_electricity_generating_capacity_per_capita'] = df['renewable_electricity_generating_capacity_per_capita'].fillna(0)

df
# Out:
#           country  year  renewable_electricity_generating_capacity_per_capita  \
# 0     Afghanistan  2000                                               9.22
# 1     Afghanistan  2001                                               8.86
# 2     Afghanistan  2002                                               8.47
# 3     Afghanistan  2003                                               8.09
# 4     Afghanistan  2004                                               7.75
# ...           ...   ...                                                ...
# 3644     Zimbabwe  2016                                              62.88
# 3645     Zimbabwe  2017                                              62.33
# 3646     Zimbabwe  2018                                              82.53
# 3647     Zimbabwe  2019                                              81.40
# 3648     Zimbabwe  2020                                              80.61
#
# ...

# %%
df.isna().sum()
# Out:
# country                                                               0
# year                                                                  0
# renewable_electricity_generating_capacity_per_capita                  0
# renewable_energy_share_in_the_total_final_energy_consumption_(%)    194
# electricity_from_fossil_fuels_(twh)                                  21
# electricity_from_nuclear_(twh)                                      126
# electricity_from_renewables_(twh)                                    21
# low_carbon_electricity_(%_electricity)                               42
# primary_energy_consumption_per_capita_(kwh/person)                    0
# energy_intensity_level_of_primary_energy_(mj/$2017_ppp_gdp)         207
# value_co2_emissions_kt_by_country                                   428
# gdp_growth                                                          317
# gdp_per_capita                                                      282
# ...

# %%
df['renewable_energy_share_in_the_total_final_energy_consumption_(%)'].tail(60)
# Out:
# 3589     0.78
# 3590     0.75
# 3591     0.74
# 3592     0.76
# 3593     0.76
# 3594     0.74
# 3595     0.70
# 3596     0.78
# 3597     0.93
# 3598     1.08
# 3599     0.76
# 3600     0.76
# 3601     1.96
# 3602     2.48
# 3603     2.80
# 3604     3.60
# 3605     3.11
# 3606      NaN
# 3607    89.98
# 3608    89.76
# 3609    89.56
# 3610    89.20
# 3611    89.28
# 3612    88.68
# 3613    89.43
# 3614    90.32
# 3615    89.36
# 3616    88.68
# 3617    88.59
# 3618    87.28
# 3619    84.63
# 3620    84.56
# 3621    83.77
# 3622    83.09
# 3623    83.07
# 3624    81.89
# 3625    82.28
# 3626    84.50
# 3627      NaN
# 3628    69.26
# 3629    71.53
# 3630    74.30
# 3631    77.83
# 3632    81.58
# 3633    80.15
# 3634    78.59
# 3635    77.97
# 3636    81.86
# 3637    82.09
# 3638    82.27
# 3639    79.27
# 3640    77.50
# 3641    78.87
# 3642    80.27
# 3643    80.82
# 3644    81.90
# 3645    82.46
# 3646    80.23
# 3647    81.50
# 3648    81.90
# ...

# %%
df['renewable_energy_share_in_the_total_final_energy_consumption_(%)'] = df['renewable_energy_share_in_the_total_final_energy_consumption_(%)'].fillna(0)

df
# Out:
#           country  year  renewable_electricity_generating_capacity_per_capita  \
# 0     Afghanistan  2000                                               9.22
# 1     Afghanistan  2001                                               8.86
# 2     Afghanistan  2002                                               8.47
# 3     Afghanistan  2003                                               8.09
# 4     Afghanistan  2004                                               7.75
# ...           ...   ...                                                ...
# 3644     Zimbabwe  2016                                              62.88
# 3645     Zimbabwe  2017                                              62.33
# 3646     Zimbabwe  2018                                              82.53
# 3647     Zimbabwe  2019                                              81.40
# 3648     Zimbabwe  2020                                              80.61
#
# ...

# %%
df['renewable_energy_share_in_the_total_final_energy_consumption_(%)'].isna().sum()
# Out:
# 0

# %%
df.head(60)
# Out:
#         country  year  renewable_electricity_generating_capacity_per_capita  \
# 0   Afghanistan  2000                                               9.22
# 1   Afghanistan  2001                                               8.86
# 2   Afghanistan  2002                                               8.47
# 3   Afghanistan  2003                                               8.09
# 4   Afghanistan  2004                                               7.75
# 5   Afghanistan  2005                                               7.51
# 6   Afghanistan  2006                                               7.40
# 7   Afghanistan  2007                                               7.25
# 8   Afghanistan  2008                                               7.49
# 9   Afghanistan  2009                                               7.50
# 10  Afghanistan  2010                                               8.27
# 11  Afghanistan  2011                                               8.13
# ...

# %%
valores_nulos = df[df['electricity_from_fossil_fuels_(twh)'].isnull()]

valores_nulos.head(60)
# Out:
#      country  year  renewable_electricity_generating_capacity_per_capita  \
# 3397  Tuvalu  2000                                               0.64
# 3398  Tuvalu  2001                                               0.63
# 3399  Tuvalu  2002                                               0.62
# 3400  Tuvalu  2003                                               0.62
# 3401  Tuvalu  2004                                               0.61
# 3402  Tuvalu  2005                                               0.60
# 3403  Tuvalu  2006                                               0.59
# 3404  Tuvalu  2007                                               0.59
# 3405  Tuvalu  2008                                               2.52
# 3406  Tuvalu  2009                                              20.07
# 3407  Tuvalu  2010                                              19.86
# 3408  Tuvalu  2011                                              19.95
# ...

# %%
df['electricity_from_fossil_fuels_(twh)'] = df['electricity_from_fossil_fuels_(twh)'].fillna(0)

df
# Out:
#           country  year  renewable_electricity_generating_capacity_per_capita  \
# 0     Afghanistan  2000                                               9.22
# 1     Afghanistan  2001                                               8.86
# 2     Afghanistan  2002                                               8.47
# 3     Afghanistan  2003                                               8.09
# 4     Afghanistan  2004                                               7.75
# ...           ...   ...                                                ...
# 3644     Zimbabwe  2016                                              62.88
# 3645     Zimbabwe  2017                                              62.33
# 3646     Zimbabwe  2018                                              82.53
# 3647     Zimbabwe  2019                                              81.40
# 3648     Zimbabwe  2020                                              80.61
#
# ...

# %%
df['electricity_from_renewables_(twh)'] = df['electricity_from_renewables_(twh)'].fillna(0)

df
# Out:
#           country  year  renewable_electricity_generating_capacity_per_capita  \
# 0     Afghanistan  2000                                               9.22
# 1     Afghanistan  2001                                               8.86
# 2     Afghanistan  2002                                               8.47
# 3     Afghanistan  2003                                               8.09
# 4     Afghanistan  2004                                               7.75
# ...           ...   ...                                                ...
# 3644     Zimbabwe  2016                                              62.88
# 3645     Zimbabwe  2017                                              62.33
# 3646     Zimbabwe  2018                                              82.53
# 3647     Zimbabwe  2019                                              81.40
# 3648     Zimbabwe  2020                                              80.61
#
# ...

# %%
valores_nulos = df[df['electricity_from_nuclear_(twh)'].isnull()]

valores_nulos.head(60)
# Out:
#          country  year  renewable_electricity_generating_capacity_per_capita  \
# 693        Chile  2000                                             290.18
# 694        Chile  2001                                             286.86
# 695        Chile  2002                                             285.57
# 696        Chile  2003                                             283.29
# 697        Chile  2004                                             327.57
# 698        Chile  2005                                             325.16
# 699        Chile  2006                                             322.11
# 700        Chile  2007                                             327.89
# 701        Chile  2008                                             331.26
# 702        Chile  2009                                             361.58
# 703        Chile  2010                                             360.95
# 704        Chile  2011                                             388.65
# ...

# %%
valores_nulos.tail(60)
# Out:
#            country  year  \
# 2020      Malaysia  2003
# 2021      Malaysia  2004
# 2022      Malaysia  2005
# 2023      Malaysia  2006
# 2024      Malaysia  2007
# 2025      Malaysia  2008
# 2026      Malaysia  2009
# 2027      Malaysia  2010
# 2028      Malaysia  2011
# 2029      Malaysia  2012
# 2030      Malaysia  2013
# 2031      Malaysia  2014
# 2032      Malaysia  2015
# 2033      Malaysia  2016
# 2034      Malaysia  2017
# 2035      Malaysia  2018
# 2036      Malaysia  2019
# 2037      Malaysia  2020
# 2871  Saudi Arabia  2000
# 2872  Saudi Arabia  2001
# 2873  Saudi Arabia  2002
# 2874  Saudi Arabia  2003
# 2875  Saudi Arabia  2004
# 2876  Saudi Arabia  2005
# 2877  Saudi Arabia  2006
# 2878  Saudi Arabia  2007
# 2879  Saudi Arabia  2008
# 2880  Saudi Arabia  2009
# 2881  Saudi Arabia  2010
# 2882  Saudi Arabia  2011
# 2883  Saudi Arabia  2012
# 2884  Saudi Arabia  2013
# 2885  Saudi Arabia  2014
# 2886  Saudi Arabia  2015
# 2887  Saudi Arabia  2016
# ...

# %%
inicio_rango = 3397
fin_rango = 3417

# Utiliza la indexación de rangos para seleccionar las filas y rellenar los nulos con 0
df.loc[inicio_rango:fin_rango, 'electricity_from_nuclear_(twh)'] = df.loc[inicio_rango:fin_rango, 'electricity_from_nuclear_(twh)'].fillna(0)

# %%
df['electricity_from_nuclear_(twh)'] = df['electricity_from_nuclear_(twh)'].fillna(0)

df
# Out:
#           country  year  renewable_electricity_generating_capacity_per_capita  \
# 0     Afghanistan  2000                                               9.22
# 1     Afghanistan  2001                                               8.86
# 2     Afghanistan  2002                                               8.47
# 3     Afghanistan  2003                                               8.09
# 4     Afghanistan  2004                                               7.75
# ...           ...   ...                                                ...
# 3644     Zimbabwe  2016                                              62.88
# 3645     Zimbabwe  2017                                              62.33
# 3646     Zimbabwe  2018                                              82.53
# 3647     Zimbabwe  2019                                              81.40
# 3648     Zimbabwe  2020                                              80.61
#
# ...

# %%
df['electricity_from_nuclear_(twh)'].value_counts()
# Out:
# electricity_from_nuclear_(twh)
# 0.00      3071
# 5.55         3
# 11.62        3
# 3.91         3
# 43.52        2
#           ...
# 436.76       1
# 421.08       1
# 415.16       1
# 23.29        1
# 789.88       1
# Name: count, Length: 547, dtype: int64

# %%
df.tail(60)
# Out:
#        country  year  renewable_electricity_generating_capacity_per_capita  \
# 3589     Yemen  2003                                               0.00
# 3590     Yemen  2004                                               0.00
# 3591     Yemen  2005                                               0.00
# 3592     Yemen  2006                                               0.00
# 3593     Yemen  2007                                               0.00
# 3594     Yemen  2008                                               0.04
# 3595     Yemen  2009                                               0.04
# 3596     Yemen  2010                                               0.04
# 3597     Yemen  2011                                               0.05
# 3598     Yemen  2012                                               0.06
# 3599     Yemen  2013                                               0.09
# 3600     Yemen  2014                                               0.19
# ...

# %%
valores_nulos = df[df['low_carbon_electricity_(%_electricity)'].isnull()]

valores_nulos.head(60)
# Out:
#       country  year  renewable_electricity_generating_capacity_per_capita  \
# 399   Bermuda  2000                                               0.00
# 400   Bermuda  2001                                               0.00
# 401   Bermuda  2002                                               0.00
# 402   Bermuda  2003                                               0.00
# 403   Bermuda  2004                                               0.00
# 404   Bermuda  2005                                               0.00
# 405   Bermuda  2006                                               0.00
# 406   Bermuda  2007                                               0.00
# 407   Bermuda  2008                                               0.00
# 408   Bermuda  2009                                               0.00
# 409   Bermuda  2010                                               0.00
# 410   Bermuda  2011                                               0.00
# ...

# %%
df['low_carbon_electricity_(%_electricity)'] = df['low_carbon_electricity_(%_electricity)'].fillna(0)

df
# Out:
#           country  year  renewable_electricity_generating_capacity_per_capita  \
# 0     Afghanistan  2000                                               9.22
# 1     Afghanistan  2001                                               8.86
# 2     Afghanistan  2002                                               8.47
# 3     Afghanistan  2003                                               8.09
# 4     Afghanistan  2004                                               7.75
# ...           ...   ...                                                ...
# 3644     Zimbabwe  2016                                              62.88
# 3645     Zimbabwe  2017                                              62.33
# 3646     Zimbabwe  2018                                              82.53
# 3647     Zimbabwe  2019                                              81.40
# 3648     Zimbabwe  2020                                              80.61
#
# ...

# %%
valores_nulos = df[df['energy_intensity_level_of_primary_energy_(mj/$2017_ppp_gdp)'].isnull()]

valores_nulos.head(60)
# Out:
#                        country  year  \
# 20                 Afghanistan  2020
# 41                     Albania  2020
# 62                     Algeria  2020
# 83                      Angola  2020
# 104        Antigua and Barbuda  2020
# 125                  Argentina  2020
# 146                    Armenia  2020
# 167                      Aruba  2020
# 188                  Australia  2020
# 209                    Austria  2020
# 230                 Azerbaijan  2020
# 251                    Bahamas  2020
# 272                    Bahrain  2020
# 293                 Bangladesh  2020
# 314                   Barbados  2020
# 335                    Belarus  2020
# 356                    Belgium  2020
# 377                     Belize  2020
# 398                      Benin  2020
# 419                    Bermuda  2020
# 440                     Bhutan  2020
# 461     Bosnia and Herzegovina  2020
# 482                   Botswana  2020
# 503                     Brazil  2020
# ...

# %%
valores_nulos = df[df['energy_intensity_level_of_primary_energy_(mj/$2017_ppp_gdp)'].isnull()]

valores_nulos.head(60)
# Out:
#                        country  year  \
# 20                 Afghanistan  2020
# 41                     Albania  2020
# 62                     Algeria  2020
# 83                      Angola  2020
# 104        Antigua and Barbuda  2020
# 125                  Argentina  2020
# 146                    Armenia  2020
# 167                      Aruba  2020
# 188                  Australia  2020
# 209                    Austria  2020
# 230                 Azerbaijan  2020
# 251                    Bahamas  2020
# 272                    Bahrain  2020
# 293                 Bangladesh  2020
# 314                   Barbados  2020
# 335                    Belarus  2020
# 356                    Belgium  2020
# 377                     Belize  2020
# 398                      Benin  2020
# 419                    Bermuda  2020
# 440                     Bhutan  2020
# 461     Bosnia and Herzegovina  2020
# 482                   Botswana  2020
# 503                     Brazil  2020
# ...

# %%
valores_nulos.tail(60)
# Out:
#                                country  year  \
# 2576                  Papua New Guinea  2020
# 2597                          Paraguay  2020
# 2618                              Peru  2020
# 2639                       Philippines  2020
# 2660                            Poland  2020
# 2681                          Portugal  2020
# 2702                       Puerto Rico  2020
# 2723                             Qatar  2020
# 2744                           Romania  2020
# 2765                            Rwanda  2020
# 2786             Saint Kitts and Nevis  2020
# 2807                       Saint Lucia  2020
# 2828  Saint Vincent and the Grenadines  2020
# 2849                             Samoa  2020
# 2870             Sao Tome and Principe  2020
# 2891                      Saudi Arabia  2020
# 2912                           Senegal  2020
# 2926                            Serbia  2020
# 2947                        Seychelles  2020
# 2968                      Sierra Leone  2020
# ...

# %%
df['energy_intensity_level_of_primary_energy_(mj/$2017_ppp_gdp)'] = df['energy_intensity_level_of_primary_energy_(mj/$2017_ppp_gdp)'].fillna(0)

df
# Out:
#           country  year  renewable_electricity_generating_capacity_per_capita  \
# 0     Afghanistan  2000                                               9.22
# 1     Afghanistan  2001                                               8.86
# 2     Afghanistan  2002                                               8.47
# 3     Afghanistan  2003                                               8.09
# 4     Afghanistan  2004                                               7.75
# ...           ...   ...                                                ...
# 3644     Zimbabwe  2016                                              62.88
# 3645     Zimbabwe  2017                                              62.33
# 3646     Zimbabwe  2018                                              82.53
# 3647     Zimbabwe  2019                                              81.40
# 3648     Zimbabwe  2020                                              80.61
#
# ...

# %%
valores_nulos = df[df['value_co2_emissions_kt_by_country'].isnull()]

valores_nulos.head(60)
# Out:
#                     country  year  \
# 20              Afghanistan  2020
# 41                  Albania  2020
# 62                  Algeria  2020
# 83                   Angola  2020
# 104     Antigua and Barbuda  2020
# 125               Argentina  2020
# 146                 Armenia  2020
# 164                   Aruba  2017
# 165                   Aruba  2018
# 166                   Aruba  2019
# 167                   Aruba  2020
# 188               Australia  2020
# 209                 Austria  2020
# 230              Azerbaijan  2020
# 231                 Bahamas  2000
# 232                 Bahamas  2001
# 233                 Bahamas  2002
# 234                 Bahamas  2003
# 235                 Bahamas  2004
# 236                 Bahamas  2005
# 237                 Bahamas  2006
# 238                 Bahamas  2007
# 239                 Bahamas  2008
# 240                 Bahamas  2009
# 241                 Bahamas  2010
# 242                 Bahamas  2011
# ...

# %%
df['value_co2_emissions_kt_by_country'] = df['value_co2_emissions_kt_by_country'].fillna('unknown')

df
# Out:
#           country  year  renewable_electricity_generating_capacity_per_capita  \
# 0     Afghanistan  2000                                               9.22
# 1     Afghanistan  2001                                               8.86
# 2     Afghanistan  2002                                               8.47
# 3     Afghanistan  2003                                               8.09
# 4     Afghanistan  2004                                               7.75
# ...           ...   ...                                                ...
# 3644     Zimbabwe  2016                                              62.88
# 3645     Zimbabwe  2017                                              62.33
# 3646     Zimbabwe  2018                                              82.53
# 3647     Zimbabwe  2019                                              81.40
# 3648     Zimbabwe  2020                                              80.61
#
# ...

# %%
df['value_co2_emissions_kt_by_country'].tail(60)
# Out:
# 3589        unknown
# 3590        unknown
# 3591        unknown
# 3592        unknown
# 3593        unknown
# 3594        unknown
# 3595        unknown
# 3596        unknown
# 3597        unknown
# 3598        unknown
# 3599        unknown
# 3600        unknown
# 3601        unknown
# 3602        unknown
# 3603        unknown
# 3604        unknown
# 3605        unknown
# 3606        unknown
# 3607         1810.0
# 3608         1840.0
# 3609    1919.999957
# 3610    2079.999924
# 3611    2109.999895
# 3612    2289.999962
# 3613    2180.000067
# 3614    1980.000019
# 3615    2190.000057
# 3616     2490.00001
# 3617    2660.000086
# 3618    3049.999952
# 3619     4030.00021
# 3620    4239.999771
# 3621    4690.000057
# 3622    4960.000038
# 3623    5320.000172
# 3624    6809.999943
# 3625    7730.000019
# 3626    6800.000191
# 3627        unknown
# 3628        13700.0
# 3629        13900.0
# 3630    12489.99977
# 3631    10180.00031
# 3632    9770.000458
# 3633    10510.00023
# ...

# %%
valores_nulos = df[df['gdp_growth'].isnull()]

valores_nulos.tail(60)
# Out:
#            country  year  \
# 2992      Slovakia  2002
# 2993      Slovakia  2003
# 2994      Slovakia  2004
# 2995      Slovakia  2005
# 2996      Slovakia  2006
# 2997      Slovakia  2007
# 2998      Slovakia  2008
# 2999      Slovakia  2009
# 3000      Slovakia  2010
# 3001      Slovakia  2011
# 3002      Slovakia  2012
# 3003      Slovakia  2013
# 3004      Slovakia  2014
# 3005      Slovakia  2015
# 3006      Slovakia  2016
# 3007      Slovakia  2017
# 3008      Slovakia  2018
# 3009      Slovakia  2019
# 3010      Slovakia  2020
# 3053       Somalia  2000
# 3054       Somalia  2001
# 3055       Somalia  2002
# 3056       Somalia  2003
# 3057       Somalia  2004
# 3058       Somalia  2005
# 3059       Somalia  2006
# 3060       Somalia  2007
# 3061       Somalia  2008
# 3062       Somalia  2009
# 3063       Somalia  2010
# 3064       Somalia  2011
# 3065       Somalia  2012
# 3066       Somalia  2013
# 3098   South Sudan  2016
# 3099   South Sudan  2017
# ...

# %%
df.loc[df['country'].isin(['Yemen', 'Somalia','Slovakia']), 'gdp_growth'] = df.loc[df['country'].isin(['Yemen', 'Somalia','Slovakia']), 'gdp_growth'].fillna(0)

# %%
df.loc[df['country'].isin(['Saint Kitts and Nevis', 'Saint Lucia','Saint Vincent and the Grenadines','Sao Tome and Principe']), 'gdp_growth'] = df.loc[df['country'].isin(['Saint Kitts and Nevis', 'Saint Lucia','Saint Vincent and the Grenadines','Sao Tome and Principe']), 'gdp_growth'].fillna(0)

# %%
df.loc[df['country'].isin(['Gambia', 'Saint Lucia','Kyrgyzstan','New Caledonia','South Sudan']), 'gdp_growth'] = df.loc[df['country'].isin(['Gambia', 'Saint Lucia','Kyrgyzstan','New Caledonia','South Sudan']), 'gdp_growth'].fillna(0)

# %%
df.loc[df['country'].isin(['Nauru', 'Czechia','Egypt','Djibouti','Eritrea']), 'gdp_growth'] = df.loc[df['country'].isin(['Nauru', 'Czechia','Egypt','Djibouti','Eritrea']), 'gdp_growth'].fillna(0)

# %%
df['gdp_growth'] = df['gdp_growth'].fillna(0)

df
# Out:
#           country  year  renewable_electricity_generating_capacity_per_capita  \
# 0     Afghanistan  2000                                               9.22
# 1     Afghanistan  2001                                               8.86
# 2     Afghanistan  2002                                               8.47
# 3     Afghanistan  2003                                               8.09
# 4     Afghanistan  2004                                               7.75
# ...           ...   ...                                                ...
# 3644     Zimbabwe  2016                                              62.88
# 3645     Zimbabwe  2017                                              62.33
# 3646     Zimbabwe  2018                                              82.53
# 3647     Zimbabwe  2019                                              81.40
# 3648     Zimbabwe  2020                                              80.61
#
# ...

# %%
valores_nulos = df[df['gdp_growth'].isnull()]

valores_nulos.tail(60)
# Out:
# Empty DataFrame
# Columns: [country, year, renewable_electricity_generating_capacity_per_capita, renewable_energy_share_in_the_total_final_energy_consumption_(%), electricity_from_fossil_fuels_(twh), electricity_from_nuclear_(twh), electricity_from_renewables_(twh), low_carbon_electricity_(%_electricity), primary_energy_consumption_per_capita_(kwh/person), energy_intensity_level_of_primary_energy_(mj/$2017_ppp_gdp), value_co2_emissions_kt_by_country, gdp_growth, gdp_per_capita, density\n(p/km2), land_area(km2)]
# Index: []

# %%
valores_nulos = df[df['gdp_per_capita'].isnull()]

valores_nulos.tail(60)
# Out:
#            country  year  \
# 2991      Slovakia  2001
# 2992      Slovakia  2002
# 2993      Slovakia  2003
# 2994      Slovakia  2004
# 2995      Slovakia  2005
# 2996      Slovakia  2006
# 2997      Slovakia  2007
# 2998      Slovakia  2008
# 2999      Slovakia  2009
# 3000      Slovakia  2010
# 3001      Slovakia  2011
# 3002      Slovakia  2012
# 3003      Slovakia  2013
# 3004      Slovakia  2014
# 3005      Slovakia  2015
# 3006      Slovakia  2016
# 3007      Slovakia  2017
# 3008      Slovakia  2018
# 3009      Slovakia  2019
# 3010      Slovakia  2020
# 3053       Somalia  2000
# 3054       Somalia  2001
# 3055       Somalia  2002
# 3056       Somalia  2003
# 3057       Somalia  2004
# 3058       Somalia  2005
# 3059       Somalia  2006
# 3060       Somalia  2007
# 3061       Somalia  2008
# 3062       Somalia  2009
# 3063       Somalia  2010
# 3064       Somalia  2011
# 3065       Somalia  2012
# 3098   South Sudan  2016
# 3099   South Sudan  2017
# ...

# %%
df['gdp_per_capita'] = df['gdp_per_capita'].fillna(0)

df
# Out:
#           country  year  renewable_electricity_generating_capacity_per_capita  \
# 0     Afghanistan  2000                                               9.22
# 1     Afghanistan  2001                                               8.86
# 2     Afghanistan  2002                                               8.47
# 3     Afghanistan  2003                                               8.09
# 4     Afghanistan  2004                                               7.75
# ...           ...   ...                                                ...
# 3644     Zimbabwe  2016                                              62.88
# 3645     Zimbabwe  2017                                              62.33
# 3646     Zimbabwe  2018                                              82.53
# 3647     Zimbabwe  2019                                              81.40
# 3648     Zimbabwe  2020                                              80.61
#
# ...

# %%
df.columns.value_counts()
# Out:
# country                                                             1
# year                                                                1
# renewable_electricity_generating_capacity_per_capita                1
# renewable_energy_share_in_the_total_final_energy_consumption_(%)    1
# electricity_from_fossil_fuels_(twh)                                 1
# electricity_from_nuclear_(twh)                                      1
# electricity_from_renewables_(twh)                                   1
# low_carbon_electricity_(%_electricity)                              1
# primary_energy_consumption_per_capita_(kwh/person)                  1
# energy_intensity_level_of_primary_energy_(mj/$2017_ppp_gdp)         1
# value_co2_emissions_kt_by_country                                   1
# gdp_growth                                                          1
# gdp_per_capita                                                      1
# ...

# %%
valores_nulos = df[df['land_area(km2)'].isnull()]

valores_nulos.tail(60)
# Out:
#             country  year  \
# 1218  French Guiana  2000
#
#       renewable_electricity_generating_capacity_per_capita  \
# 1218                                             702.29
#
#       renewable_energy_share_in_the_total_final_energy_consumption_(%)  \
# 1218                                              23.84
#
#       electricity_from_fossil_fuels_(twh)  electricity_from_nuclear_(twh)  \
# 1218                                 0.43                             0.0
#
#       electricity_from_renewables_(twh)  \
# 1218                                0.0
#
#       low_carbon_electricity_(%_electricity)  \
# 1218                                     0.0
#
#       primary_energy_consumption_per_capita_(kwh/person)  \
# 1218                                          13692.394
#
#       energy_intensity_level_of_primary_energy_(mj/$2017_ppp_gdp)  \
# 1218                                                0.0
#
#      value_co2_emissions_kt_by_country  gdp_growth  gdp_per_capita  \
# ...

# %%
nuevo_df = df[df['country'] == 'French Guiana']

nuevo_df.head(60)
# Out:
#             country  year  \
# 1218  French Guiana  2000
#
#       renewable_electricity_generating_capacity_per_capita  \
# 1218                                             702.29
#
#       renewable_energy_share_in_the_total_final_energy_consumption_(%)  \
# 1218                                              23.84
#
#       electricity_from_fossil_fuels_(twh)  electricity_from_nuclear_(twh)  \
# 1218                                 0.43                             0.0
#
#       electricity_from_renewables_(twh)  \
# 1218                                0.0
#
#       low_carbon_electricity_(%_electricity)  \
# 1218                                     0.0
#
#       primary_energy_consumption_per_capita_(kwh/person)  \
# 1218                                          13692.394
#
#       energy_intensity_level_of_primary_energy_(mj/$2017_ppp_gdp)  \
# 1218                                                0.0
#
#      value_co2_emissions_kt_by_country  gdp_growth  gdp_per_capita  \
# ...

# %%
df['country'].value_counts()
# Out:
# country
# Afghanistan      21
# Oman             21
# Netherlands      21
# New Caledonia    21
# New Zealand      21
#                  ..
# Zimbabwe         21
# Serbia           14
# Montenegro       14
# South Sudan       8
# French Guiana     1
# Name: count, Length: 176, dtype: int64

# %%
df['land_area(km2)'] = df['land_area(km2)'].fillna(0)

df
# Out:
#           country  year  renewable_electricity_generating_capacity_per_capita  \
# 0     Afghanistan  2000                                               9.22
# 1     Afghanistan  2001                                               8.86
# 2     Afghanistan  2002                                               8.47
# 3     Afghanistan  2003                                               8.09
# 4     Afghanistan  2004                                               7.75
# ...           ...   ...                                                ...
# 3644     Zimbabwe  2016                                              62.88
# 3645     Zimbabwe  2017                                              62.33
# 3646     Zimbabwe  2018                                              82.53
# 3647     Zimbabwe  2019                                              81.40
# 3648     Zimbabwe  2020                                              80.61
#
# ...

# %%
df = df.drop((['density(p/km2)']), axis=1)

df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 df = df.drop((['density(p/km2)']), axis=1)
#       3 df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# ...

# %%
#df['density\n(p/km2)']

df.columns = df.columns.str.lower().str.replace('\n', '_')

# %%
df.rename(columns={'density\n(p/km2)': 'density_(p/km2)'}, inplace=True)

# %%
df.isna().sum()
# Out:
# country                                                             0
# year                                                                0
# renewable_electricity_generating_capacity_per_capita                0
# renewable_energy_share_in_the_total_final_energy_consumption_(%)    0
# electricity_from_fossil_fuels_(twh)                                 0
# electricity_from_nuclear_(twh)                                      0
# electricity_from_renewables_(twh)                                   0
# low_carbon_electricity_(%_electricity)                              0
# primary_energy_consumption_per_capita_(kwh/person)                  0
# energy_intensity_level_of_primary_energy_(mj/$2017_ppp_gdp)         0
# value_co2_emissions_kt_by_country                                   0
# gdp_growth                                                          0
# gdp_per_capita                                                      0
# ...

# %%
df.head()
# Out:
#        country  year  renewable_electricity_generating_capacity_per_capita  \
# 0  Afghanistan  2000                                               9.22
# 1  Afghanistan  2001                                               8.86
# 2  Afghanistan  2002                                               8.47
# 3  Afghanistan  2003                                               8.09
# 4  Afghanistan  2004                                               7.75
#
#    renewable_energy_share_in_the_total_final_energy_consumption_(%)  \
# 0                                              44.99
# 1                                              45.60
# 2                                              37.83
# 3                                              36.66
# 4                                              44.24
#
#    electricity_from_fossil_fuels_(twh)  electricity_from_nuclear_(twh)  \
# 0                                 0.16                             0.0
# ...

# %%
nuevo_df = df[df['year'] == 2020]

nuevo_df.head(60)

# %%
df.isna().sum()
